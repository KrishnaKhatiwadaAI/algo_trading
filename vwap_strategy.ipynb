# %%
import pandas as pd
from dotenv import load_dotenv, find_dotenv
import os
import sqlalchemy as sq

load_dotenv(find_dotenv())
host = os.getenv("DB_HOST")
db_pass = os.getenv("DB_PASSWORD")
db_user = os.getenv("DB_USERNAME")
db_database = os.getenv("DATABASE")

# %%
# creating sql instance
engine = sq.create_engine(
    f'mysql+pymysql://{db_user}:{db_pass}@{host}:3306/{db_database}')

# %%
df=pd.read_sql('todayshare',engine)

# %%
df.drop_duplicates(subset=['Date','Traded Companies'],inplace=True)
df.drop(columns=['index'],inplace=True)

# %%
columns_x = ['Amount', 'Closing Price', 'Max Price',
             'Min Price', 'Previous Closing', 'Traded Shares']

# %%
def numerical_data_maker(df, columns):
    for i in columns:
        if type(list(df[i])[0]) == float or int:
            df[i] = pd.to_numeric(df[i])
        else:
            df[i] = pd.to_numeric(df[i].str.replace(',', ''))
    return df

# %%
df=numerical_data_maker(df,columns_x)

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.sort_values('Date',ascending=False,inplace=True)

# %%
df.columns
# Out:
# Index(['Traded Companies', 'No. Of Transaction', 'Max Price', 'Min Price',
#        'Closing Price', 'Traded Shares', 'Amount', 'Previous Closing',
#        'Difference Rs.', 'Date'],
#       dtype='object')

# %%
def vwap(df,vol_col_name,price_col_name):
    traded_amount = df[vol_col_name].values
    closing_price = df[price_col_name].values
#     return df.assign(vwap=(closing_price * traded_amount).cumsum() / traded_amount.cumsum())

df_adbl = df[df['Traded Companies']=='Agriculture Development Bank Limited']
adbl_vwap = vwap_values=vwap(df_adbl,'Amount','Closing Price')
df_adbl=df_adbl[df_adbl['Closing Price']!=0]

# %%
v = df_adbl['Amount'].values
tp = (df_adbl['Min Price'] + df_adbl['Closing Price'] + df_adbl['Max Price']).div(3).values

# %%
vwap=(tp * v).cumsum() / v.cumsum()

# %%
vwap
# Out:
# array([565.56666667, 567.60498059, 569.12178638, ..., 513.31879626,
#        513.29866231, 513.28444802])

# %%
vwap_in_list = []
for i in range(len(tp)):
    limit = 7+i
    vwap_in_list += [np.sum(tp[:limit]*v[:limit])/np.sum(v[:limit])]

# %%
df_adbl['vwap']=vwap_in_list

# %%
np.sum(tp[:limit]*v[:limit])/np.sum(v[:limit])
# Out:
# 513.284448018968

# %%
import plotly.graph_objects as go
import numpy as np

N = 1000
t = np.linspace(0, 10, 100)
y = np.sin(t)

fig = go.Figure(data=go.Scatter(y=df_adbl['vwap'],x=df_adbl['Date'] , mode='markers',name='VWAP'))
fig.add_trace(go.Scatter(y=df_adbl['Closing Price'],x=df_adbl['Date'],mode='lines',name='Closing Price'))
fig.add_trace(go.Scatter(y=df_adbl['Closing Price']-df_adbl['vwap'],x=df_adbl['Date'],mode='lines',name='Diff'))

fig.show()
# Out:
# <div>                            <div id="151d28dd-de0c-4a55-8e7f-a514c2c66289" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("151d28dd-de0c-4a55-8e7f-a514c2c66289")) {                    Plotly.newPlot(                        "151d28dd-de0c-4a55-8e7f-a514c2c66289",                        [{"mode": "markers", "name": "VWAP", "type": "scatter", "x": ["2021-08-29T00:00:00", "2021-08-26T00:00:00", "2021-08-25T00:00:00", "2021-08-24T00:00:00", "2021-08-19T00:00:00", "2021-08-18T00:00:00", "2021-08-17T00:00:00", "2021-08-16T00:00:00", "2021-08-15T00:00:00", "2021-08-12T00:00:00", "2021-08-11T00:00:00", "2021-08-10T00:00:00", "2021-08-09T00:00:00", "2021-08-08T00:00:00", "2021-08-05T00:00:00", "2021-08-04T00:00:00", "2021-08-03T00:00:00", "2021-08-02T00:00:00", "2021-08-01T00:00:00", "2021-07-29T00:00:00", "2021-07-28T00:00:00", "2021-07-27T00:00:00", "2021-07-26T00:00:00", "2021-07-25T00:00:00", "2021-07-22T00:00:00", "2021-07-20T00:00:00", "2021-07-19T00:00:00", "2021-07-18T00:00:00", "2021-07-15T00:00:00", "2021-07-14T00:00:00", "2021-07-13T00:00:00", "2021-07-12T00:00:00", "2021-07-11T00:00:00", "2021-07-08T00:00:00", "2021-07-07T00:00:00", "2021-07-06T00:00:00", "2021-07-05T00:00:00", "2021-07-04T00:00:00", "2021-07-01T00:00:00", "2021-06-30T00:00:00", "2021-06-29T00:00:00", "2021-06-28T00:00:00", "2021-06-27T00:00:00", "2021-06-24T00:00:00", "2021-06-23T00:00:00", "2021-06-22T00:00:00", "2021-06-21T00:00:00", "2021-06-20T00:00:00", "2021-06-17T00:00:00", "2021-06-16T00:00:00", "2021-06-15T00:00:00", "2021-06-14T00:00:00", "2021-06-13T00:00:00", "2021-06-10T00:00:00", "2021-06-09T00:00:00", "2021-06-08T00:00:00", "2021-06-07T00:00:00", "2021-06-06T00:00:00", "2021-06-03T00:00:00", "2021-06-02T00:00:00", "2021-06-01T00:00:00", "2021-05-31T00:00:00", "2021-05-30T00:00:00", "2021-05-27T00:00:00", "2021-05-25T00:00:00", "2021-05-24T00:00:00", "2021-05-23T00:00:00", "2021-05-20T00:00:00", "2021-05-19T00:00:00", "2021-05-18T00:00:00", "2021-05-17T00:00:00", "2021-05-16T00:00:00", "2021-05-13T00:00:00", "2021-05-12T00:00:00", "2021-05-11T00:00:00", "2021-05-10T00:00:00", "2021-05-09T00:00:00", "2021-05-06T00:00:00", "2021-05-05T00:00:00", "2021-05-04T00:00:00", "2021-05-03T00:00:00", "2021-05-02T00:00:00", "2021-04-29T00:00:00", "2021-04-28T00:00:00", "2021-04-27T00:00:00", "2021-04-26T00:00:00", "2021-04-25T00:00:00", "2021-04-22T00:00:00", "2021-04-21T00:00:00", "2021-04-20T00:00:00", "2021-04-19T00:00:00", "2021-04-18T00:00:00", "2021-04-15T00:00:00", "2021-04-13T00:00:00", "2021-04-12T00:00:00", "2021-04-08T00:00:00", "2021-04-07T00:00:00", "2021-04-06T00:00:00", "2021-04-05T00:00:00", "2021-04-04T00:00:00", "2021-04-01T00:00:00", "2021-03-31T00:00:00", "2021-03-30T00:00:00", "2021-03-29T00:00:00", "2021-03-25T00:00:00", "2021-03-24T00:00:00", "2021-03-23T00:00:00", "2021-03-22T00:00:00", "2021-03-21T00:00:00", "2021-03-18T00:00:00", "2021-03-17T00:00:00", "2021-03-16T00:00:00", "2021-03-15T00:00:00", "2021-03-14T00:00:00", "2021-03-10T00:00:00", "2021-03-09T00:00:00", "2021-03-07T00:00:00", "2021-03-04T00:00:00", "2021-03-03T00:00:00", "2021-03-02T00:00:00", "2021-03-01T00:00:00", "2021-02-28T00:00:00", "2021-02-25T00:00:00", "2021-02-24T00:00:00", "2021-02-23T00:00:00", "2021-02-22T00:00:00", "2021-02-21T00:00:00", "2021-02-18T00:00:00", "2021-02-17T00:00:00", "2021-02-16T00:00:00", "2021-02-15T00:00:00", "2021-02-14T00:00:00", "2021-02-11T00:00:00", "2021-02-10T00:00:00", "2021-02-09T00:00:00", "2021-02-08T00:00:00", "2021-02-07T00:00:00", "2021-02-04T00:00:00", "2021-02-03T00:00:00", "2021-02-02T00:00:00", "2021-02-01T00:00:00", "2021-01-31T00:00:00", "2021-01-28T00:00:00", "2021-01-27T00:00:00", "2021-01-26T00:00:00", "2021-01-25T00:00:00", "2021-01-24T00:00:00", "2021-01-21T00:00:00", "202 ...

# %%
df_adbl['diff']=df['Closing Price']-df_adbl['vwap']

# %%
df_adbl[['vwap','diff','Closing Price']].describe()
# Out:
#               vwap         diff  Closing Price
# count  2422.000000  2422.000000    2422.000000
# mean    503.829611  -117.029755     386.799855
# std      21.447336   175.354496     172.624491
# min     470.070431  -413.504544     101.000000
# 25%     481.081854  -260.782546     257.250000
# 50%     514.030502   -80.679260     418.000000
# 75%     518.091390   -32.636002     473.000000
# max     590.213130   576.696492    1082.000000

# %%
# percentage of time that vwap is lower than the closing price
per_vwap_more_than_cp=df_adbl[df_adbl['Closing Price']>df_adbl['vwap']].shape[0]/df_adbl.shape[0]
# percentage of time that vwap is more than the closing price
per_vwap_less_than_cp=df_adbl[df_adbl['Closing Price']<df_adbl['vwap']].shape[0]/df_adbl.shape[0]

# %%
df_adbl['vwap_diff']=(df_adbl['diff']*100/df_adbl['vwap'])

# %%
df_adbl['vwap_diff'].describe()
# Out:
# count    2422.000000
# mean      -22.974642
# std        34.416543
# min       -80.369464
# 25%       -50.395866
# 50%       -15.995696
# 75%        -6.674598
# max       118.102058
# Name: vwap_diff, dtype: float64

# %%
fig = go.Figure(data=[go.Histogram(y=df_adbl['vwap_diff'],histnorm='probability')])

fig.show()
# Out:
# <div>                            <div id="bc99370d-ac64-47c2-bf8f-1dd32003a95b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bc99370d-ac64-47c2-bf8f-1dd32003a95b")) {                    Plotly.newPlot(                        "bc99370d-ac64-47c2-bf8f-1dd32003a95b",                        [{"histnorm": "probability", "type": "histogram", "y": [-4.230098703008236, -2.6156531706343302, -3.0692335472167183, -1.3819427939815663, 0.0486044073667611, 0.8335398637339544, -0.9716336358879957, 0.1241116427912912, 0.8764485683206601, 0.7661787350431768, 0.13970133490257644, 0.9215536764620587, -1.1454397036752892, -0.861205654368009, -0.9386185360272671, -0.303343655455212, -0.7159955752960808, -2.0885427991376195, -2.7844205811428195, -1.63802305994924, -1.296295924182087, -0.032033530896657905, 0.8038472187748807, 4.032753436253404, 2.616071583211966, -4.745965330267763, -10.394005985967878, -10.991800454019144, -15.928577924831009, -15.845765375031668, -15.427391089509264, -15.50996022289328, -13.927217753438557, -15.7846919117714, -16.737932754609325, -16.15950254230562, -15.398344910879324, -14.968063401179371, -13.607170823938956, -13.786710920614778, -13.022984249655934, -10.613617061687872, -11.183003703986932, -12.901622684311548, -14.51996957489947, -12.232764847485944, -14.232868110942125, -13.045814835219732, -10.366213257335389, -9.76811929144893, -10.458416595208629, -11.767989160031606, -14.69405776618911, -15.344947571139665, -14.32250436513376, -14.058729569056625, -14.800864255552606, -13.205246831462341, -16.13323469085286, -17.783390034304908, -18.235070701320172, -17.23148325252269, -16.004737788042743, -16.667228914588048, -16.230415253369387, -15.021287307508635, -16.28124374820509, -17.742583682497933, -18.061286628866924, -18.395553846150065, -19.282802129743533, -19.79670186647937, -20.868434947327312, -20.81407363620898, -20.36370670738867, -20.48678006712013, -20.620095612463, -20.950993662844464, -20.84406993692754, -20.748638713073415, -20.501099052428, -19.300473685467708, -20.183710694664033, -20.87793504011965, -20.616043392511042, -21.315927743088587, -19.91271791044423, -18.103989503972866, -17.852030180562256, -17.620935117935712, -17.01749541670358, -15.43847493528923, -14.061081637968645, -14.571552289505684, -16.047255016251494, -15.953924305054892, -15.92679372091826, -15.90054308456841, -15.847537959827514, -15.034576023844464, -15.397871150588264, -14.210845613019501, -17.454493938620292, -17.228398667380237, -16.82383650886593, -17.170920313682597, -17.52840451308132, -17.0961504263317, -15.51125123393388, -16.831477158043214, -18.12377464166212, -19.236299892879227, -19.171890964198038, -18.92340578745819, -17.306958669935252, -17.242537043766145, -16.428561721604016, -15.60837609519026, -16.736460362390062, -15.322690901857188, -13.32486922479154, -14.05057621231094, -11.257387237205226, -10.417492358795498, -11.160834201128411, -9.368016072918744, -7.573342486673278, -7.746978968735938, -8.690480733670363, -9.61140944813173, -10.74120985615428, -12.259665281271927, -11.618385130329985, -10.394698021129194, -11.154507129180805, -9.3159936771772, -11.614389835816686, -11.385677375879267, -11.315517304085763, -11.4464334288017, -12.199719051898269, -12.370088963101752, -9.586457094366398, -7.380315275640659, -4.584444834565201, -9.287902261497907, -12.021157932201513, -12.402777846589139, -12.37237463425541, -11.33305175659243, -11.505547658167751, -10.495590865610623, -11.073491944280054, -10.264833346152795, -10.828413196001232, -10.990160514773224, -13.34244550374952, -13.327190623547766, -13.916050610093425, -13.11893486617692, -12.914462510545565, -15.882130716051991, -16.470468343523116, -3.384622991696858, -2.5847443153325145, -2.4028865345046526, -2.4 ...
